# %% [markdown]
# ### Importing a user defined Module & Calling a function from that Module
#
# Priyaranjan Mohanty

# %% [markdown]
# I have already defined a Python module in the home directory ..
#
# the module is saved as "Python_Module.py"
#
# Note - Dont create the Module.py using Jupyter notebook as its saves some other formatting info.
#
# We can create the Module.py using Notepad / Pycharm /Spyder etc ..
#
# and the content of the module is -
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### How to use that user defined Module in this Program ...
#
# Step 1 : Import that User defined Module
#
# Step 2 : and then invoke the functions / methods defined in that module

# %%
import Python_Module

# %%
dir(Python_Module)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'print_func']

# %%
Python_Module.print_func('PRM')
# Out:
# Hello :  PRM
